# %%
HEADERS = {
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
    'Accept-Language': 'pt-BR,pt;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'Connection': 'keep-alive',
    'Sec-Fetch-Dest': 'document',
    'Sec-Fetch-Mode': 'navigate',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-User': '?1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36 Edg/145.0.0.0',
    'sec-ch-ua': '"Not:A-Brand";v="99", "Microsoft Edge";v="145", "Chromium";v="145"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    # 'Cookie': 'lgpd-cookie-v2={"v":7,"g":[{"id":"cookies-estritamente-necessarios","on":true},{"id":"cookies-de-desempenho","on":true},{"id":"cookies-de-terceiros","on":true}]}; _fbp=fb.2.1762802006895.597212056308951418; _tt_enable_cookie=1; _ttp=01K9QJZZ6MDP9XY4WEQG4NNTBY_.tt.2; _gcl_au=1.1.2002285091.1770750083; Encrypted-Local-Storage-Key=N6u/NRWe2mEq9UMCpGHhdD3KBA68uCM5BQwuI1V+96Q; ttcsid=1771549106857::tLMQJAg2V-9Xfm0bZulc.47.1771549162814.0::1.55317.55750::5548.1.456.2256::1491.7.1600; ttcsid_CJVHHJ3C77U20ERJTS3G=1771549106857::PNN-CSJfXlvKxeK2swm4.15.1771549162814.1',
}

COOKIES = {
    'lgpd-cookie-v2': '{"v":7,"g":[{"id":"cookies-estritamente-necessarios","on":true},{"id":"cookies-de-desempenho","on":true},{"id":"cookies-de-terceiros","on":true}]}',
    '_fbp': 'fb.2.1762802006895.597212056308951418',
    '_tt_enable_cookie': '1',
    '_ttp': '01K9QJZZ6MDP9XY4WEQG4NNTBY_.tt.2',
    '_gcl_au': '1.1.2002285091.1770750083',
    'Encrypted-Local-Storage-Key': 'N6u/NRWe2mEq9UMCpGHhdD3KBA68uCM5BQwuI1V+96Q',
    'ttcsid': '1771549106857::tLMQJAg2V-9Xfm0bZulc.47.1771549162814.0::1.55317.55750::5548.1.456.2256::1491.7.1600',
    'ttcsid_CJVHHJ3C77U20ERJTS3G': '1771549106857::PNN-CSJfXlvKxeK2swm4.15.1771549162814.1',
}

# %%
import requests
from bs4 import BeautifulSoup as bs
import os

r = requests.get('https://www.gov.br/cgu/pt-br/acesso-a-informacao/dados-abertos/arquivos/terceirizados')

soup = bs(r.text, 'html.parser')

os.makedirs('input', exist_ok=True)

for x in soup.find_all('a', class_="internal-link", href=True):
    if x['href'].endswith(('.csv', '.xlsx')):
        print(f"Downloading {x['href']}...")
        filename = x['href'].split('/')[-1]
        filepath = os.path.join('input', filename)
        if os.path.exists(filepath):
            print(f"{filename} already exists, skipping.")
            continue
        
        print(f"Saving to {filepath}...")

        response = requests.get(x['href'], cookies=COOKIES, headers=HEADERS)
        response.raise_for_status()

        with open(filepath, 'wb') as f:
            f.write(response.content)

# %%
import pandas as pd

# %%
COLUMNS = [
        'id_terc',
        'sg_orgao_sup_tabela_ug',
        'cd_ug_gestora',
        'nm_ug_tabela_ug',
        'sg_ug_gestora',
        'nr_contrato',
        'nr_cnpj',
        'nm_razao_social',
        'nr_cpf',
        'nm_terceirizado',
        'nm_categoria_profissional',
        'nm_escolaridade',
        'nr_jornada',
        'nm_unidade_prestacao',
        'vl_mensal_salario',
        'vl_mensal_custo',
        'Num_Mes_Carga',
        'Mes_Carga',
        'Ano_Carga',
        'sg_orgao',
        'nm_orgao',
        'cd_orgao_siafi',
        'cd_orgao_siape'
    ]

# %%
if COLUMNS == pd.read_csv('input/terceirizados202309.csv', sep=';', encoding='utf-8', nrows=0).columns.tolist():
    print("Columns match, proceeding to read the full dataset.")
# Out:
# Columns match, proceeding to read the full dataset.

# %%
pd.read_csv('input/terceirizados_202005.csv', dtype=str, encoding='latin1', sep=';')
# Out:
#        id_terc sg_orgao_sup_tabela_ug cd_ug_gestora  \
# 0      7720611               M.CIDADA        550005
# 1      7720612               M.CIDADA        550005
# 2      7720613               M.CIDADA        550005
# 3      7720614               M.CIDADA        550005
# 4      7720615               M.CIDADA        550005
# ...        ...                    ...           ...
# 77367  7796005                   MJSP        200406
# 77368  7796006                   MJSP        200406
# 77369  7796007                   MJSP        200406
# 77370  7796008                   MJSP        200406
# 77371  7796009                   MJSP        200406
#
#                                    nm_ug_tabela_ug     sg_ug_gestora  \
# 0      COORDENACAO GERAL DE LICITACOES E CONTRATOS  C.G.L.C./ M.D.S.
# 1      COORDENACAO GERAL DE LICITACOES E CONTRATOS  C.G.L.C./ M.D.S.
# 2      COORDENACAO GERAL DE LICITACOES E CONTRATOS  C.G.L.C./ M.D.S.
# 3      COORDENACAO GERAL DE LICITACOES E CONTRATOS  C.G.L.C./ M.D.S.
# 4      COORDENACAO GERAL DE LICITACOES E CONTRATOS  C.G.L.C./ M.D.S.
# ...                                            ...               ...
# 77367      DIRETORIA TECNICO-CIENTIFICA - DITEC/PF         DITEC/DPF
# 77368      DIRETORIA TECNICO-CIENTIFICA - DITEC/PF         DITEC/DPF
# 77369      DIRETORIA TECNICO-CIENTIFICA - DITEC/PF         DITEC/DPF
# 77370      DIRETORIA TECNICO-CIENTIFICA - DITEC/PF         DITEC/DPF
# 77371      DIRETORIA TECNICO-CIENTIFICA - DITEC/PF         DITEC/DPF
#
#       nr_contrato         nr_cnpj  \
# 0         28/2017  11054815000170
# 1         28/2017  11054815000170
# 2         28/2017  11054815000170
# 3         28/2017  11054815000170
# 4         28/2017  11054815000170
# ...           ...             ...
# 77367     18/2019  04762861000168
# 77368     18/2019  04762861000168
# 77369     18/2019  04762861000168
# 77370     18/2019  04762861000168
# 77371     18/2019  04762861000168
#
#                                     nm_razao_social          nr_cpf  \
# 0      AD'S SERVICOS DE LOCACAO DE MAO DE OBRA LTDA  ***.197.991-**
# 1      AD'S SERVICOS DE LOCACAO DE MAO DE OBRA LTDA  ***.652.728-**
# 2      AD'S SERVICOS DE LOCACAO DE MAO DE OBRA LTDA  ***.571.131-**
# 3      AD'S SERVICOS DE LOCACAO DE MAO DE OBRA LTDA  ***.666.231-**
# 4      AD'S SERVICOS DE LOCACAO DE MAO DE OBRA LTDA  ***.150.821-**
# ...                                             ...             ...
# 77367                      ENGEPROM ENGENHARIA LTDA  ***.124.531-**
# 77368                      ENGEPROM ENGENHARIA LTDA  ***.019.571-**
# 77369                      ENGEPROM ENGENHARIA LTDA  ***.476.911-**
# 77370                      ENGEPROM ENGENHARIA LTDA  ***.893.343-**
# 77371                      ENGEPROM ENGENHARIA LTDA  ***.741.114-**
#
#                           nm_terceirizado  \
# 0                    LORENA MARQUES GOMES
# 1       AMELIA EVANGELISTA FERNANDES LIMA
# 2       TANIA MARCIA SCHEID NINAUT DUARTE
# 3              GIDALVA VALDEVINO DE SOUSA
# 4            KARLA DA SILVA REZENDE ALVES
# ...                                   ...
# 77367          FRANCISCO DAS CHAGAS ALVES
# 77368    FLAVIO RODRIGUES DE FARIAS FILHO
# 77369               FLAVIO VIEIRA CARDOSO
# 77370  ANTONIO DE PADUA CARDOSO FONTENELE
# 77371             EUFEMIO DA MATA RIBEIRO
#
#                                nm_categoria_profissional  \
# 0                    252305 - SECRETARIA(O) EXECUTIVA(O)
# 1                    252305 - SECRETARIA(O) EXECUTIVA(O)
# 2                    252305 - SECRETARIA(O) EXECUTIVA(O)
# 3                    252305 - SECRETARIA(O) EXECUTIVA(O)
# 4                    252305 - SECRETARIA(O) EXECUTIVA(O)
# ...                                                  ...
# 77367  723310 - PINTOR A PINCEL E ROLO (EXCETO OBRAS ...
# 77368  951105 - ELETRICISTA DE MANUTENCAO ELETROELETR...
# 77369          313205 - TECNICO DE MANUTENCAO ELETRONICA
# 77370            514310 - AUXILIAR DE MANUTENCAO PREDIAL
# 77371                               724440 - SERRALHEIRO
#
#                    nm_escolaridade nr_jornada  \
# 0                SUPERIOR COMPLETO       40
# 1                SUPERIOR COMPLETO       40
# 2                SUPERIOR COMPLETO       40
# 3                SUPERIOR COMPLETO       40
# 4                SUPERIOR COMPLETO       40
# ...                            ...        ...
# 77367  ENSINO FUNDAMENTAL COMPLETO       44
# 77368       CURSO TECNICO COMPLETO       41
# 77369       CURSO TECNICO COMPLETO       44
# 77370  ENSINO FUNDAMENTAL COMPLETO       44
# 77371  ENSINO FUNDAMENTAL COMPLETO       44
#
#                        nm_unidade_prestacao  vl_mensal_salario  \
# 0                    MC/BLOCO A - ESPLANADA  4036.360107421875
# 1                    MC/BLOCO B - ESPLANADA  4036.360107421875
# 2                    MC/BLOCO A - ESPLANADA  4036.360107421875
# 3                    MC/BLOCO B - ESPLANADA  4036.360107421875
# 4                    MC/BLOCO B - ESPLANADA  4036.360107421875
# ...                                     ...                ...
# 77367  COMPLEXO DA PF NO SETOR POLICIAL SUL  1397.300048828125
# 77368  COMPLEXO DA PF NO SETOR POLICIAL SUL  2046.719970703125
# 77369  COMPLEXO DA PF NO SETOR POLICIAL SUL    1857.9599609375
# 77370  COMPLEXO DA PF NO SETOR POLICIAL SUL             1184.0
# 77371  COMPLEXO DA PF NO SETOR POLICIAL SUL  1397.300048828125
#
#         vl_mensal_custo Num_Mes_Carga Mes_Carga Ano_Carga sg_orgao  \
# 0          8226.4296875             5      MAIO      2020      MDS
# 1          8226.4296875             5      MAIO      2020      MDS
# 2          8226.4296875             5      MAIO      2020      MDS
# 3          8226.4296875             5      MAIO      2020      MDS
# 4          8226.4296875             5      MAIO      2020      MDS
# ...                 ...           ...       ...       ...      ...
# 77367  3795.97998046875             5      MAIO      2020      DPF
# 77368    4854.740234375             5      MAIO      2020      DPF
# 77369    4710.990234375             5      MAIO      2020      DPF
# 77370    3388.330078125             5      MAIO      2020      DPF
# 77371  3795.97998046875             5      MAIO      2020      DPF
#
#                                    nm_orgao cd_orgao_siafi cd_orgao_siape
# 0      MINISTERIO DO DESENVOLVIMENTO SOCIAL          55000          55000
# 1      MINISTERIO DO DESENVOLVIMENTO SOCIAL          55000          55000
# 2      MINISTERIO DO DESENVOLVIMENTO SOCIAL          55000          55000
# 3      MINISTERIO DO DESENVOLVIMENTO SOCIAL          55000          55000
# 4      MINISTERIO DO DESENVOLVIMENTO SOCIAL          55000          55000
# ...                                     ...            ...            ...
# 77367       DEPARTAMENTO DE POLICIA FEDERAL          30108          20115
# 77368       DEPARTAMENTO DE POLICIA FEDERAL          30108          20115
# 77369       DEPARTAMENTO DE POLICIA FEDERAL          30108          20115
# 77370       DEPARTAMENTO DE POLICIA FEDERAL          30108          20115
# 77371       DEPARTAMENTO DE POLICIA FEDERAL          30108          20115
#
# [77372 rows x 23 columns]

# %%
if COLUMNS == pd.read_csv('input/terceirizados-201901_1.csv', sep=';', encoding='utf-8', nrows=0).columns.tolist():
    print("Columns match, proceeding to read the full dataset.")
    
    df = pd.read_csv('input/terceirizados-201901_1.csv', sep=';', encoding='utf-8')
else:
# Out:
# Empty DataFrame
# Columns: [7070352, M.J, 200109, DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL, DPRF, 06/2018, 06311155000125, CS SEGURACA E VIGILANCIA LTDA, ***.896.391-**, FRANCISCO DOS SANTOS FRANCA, 517330 - VIGILANTE, ENSINO FUNDAMENTAL INCOMPLETO, 48  , PRF, 2012,55, 13101,44, 1, JANEIRO, 2019, DPRF/MJ, DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL/MJ, 30802, 30802.1]
# Index: []

# %%
df = pd.read_csv('input/terceirizados-201901_1.csv', sep=';', encoding='utf-8', header=COLUMNS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 df = pd.read_csv('input/terceirizados-201901_1.csv', sep=';', encoding='utf-8', header=COLUMNS)
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1639, in TextFileReader.__init__(self, f, engine, **kwds)
#    1636 self.nrows = options.pop("nrows", None)
#    1638 self._check_file_or_buffer(f, engine)
# -> 1639 self.options, self.engine = self._clean_options(options, engine)
#    1641 if "has_index_names" in kwds:
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parsers/readers.py:1811, in TextFileReader._clean_options(self, options, engine)
#    1808 na_values = options["na_values"]
#    1809 skiprows = options["skiprows"]
# -> 1811 validate_header_arg(options["header"])
#    1813 if index_col is True:
#    1814     raise ValueError("The value of index_col couldn't be 'True'")
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/common.py:214, in validate_header_arg(header)
#     212 header = cast(Sequence, header)
#     213 if not all(map(is_integer, header)):
# --> 214     raise ValueError("header must be integer or list of integers")
#     215 if any(i < 0 for i in header):
#     216     raise ValueError("cannot specify multi-index header with negative integers")
#
# ValueError: header must be integer or list of integers

# %%
df.head()
# Out:
#    7070352  M.J  200109  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL  DPRF  \
# 0  7070353  M.J  200109  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL  DPRF
# 1  7070354  M.J  200109  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL  DPRF
# 2  7070355  M.J  200109  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL  DPRF
# 3  7070356  M.J  200109  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL  DPRF
# 4  7070357  M.J  200109  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL  DPRF
#
#    06/2018  06311155000125      CS SEGURACA E VIGILANCIA LTDA  ***.896.391-**  \
# 0  06/2018   6311155000125      CS SEGURACA E VIGILANCIA LTDA  ***.216.411-**
# 1  06/2018   6311155000125      CS SEGURACA E VIGILANCIA LTDA  ***.016.241-**
# 2  06/2018   6311155000125      CS SEGURACA E VIGILANCIA LTDA  ***.637.605-**
# 3  06/2018   6311155000125      CS SEGURACA E VIGILANCIA LTDA  ***.915.401-**
# 4  10/2017   8247960000162  REAL JG SERVICOS GERAIS EIRELLI  ***.253.853-**
#
#    FRANCISCO DOS SANTOS FRANCA                      517330 - VIGILANTE  \
# 0      EDSON BORGES DOS SANTOS                      517330 - VIGILANTE
# 1     MARCELO MARTINS DE SOUZA                      517330 - VIGILANTE
# 2  BENILTON ALCANTARA DE MATOS                      517330 - VIGILANTE
# 3       JAISON GUILHERME BRAGA                      517330 - VIGILANTE
# 4  CLEBER SALES PINTO DA SILVA  782305 - MOTORISTA DE CARRO DE PASSEIO
#
#    ENSINO FUNDAMENTAL INCOMPLETO  48     PRF  2012,55  13101,44  1  JANEIRO  \
# 0  ENSINO FUNDAMENTAL INCOMPLETO  48     PRF  2012,55  12080,44  1  JANEIRO
# 1  ENSINO FUNDAMENTAL INCOMPLETO  48     PRF  2012,55  12080,44  1  JANEIRO
# 2  ENSINO FUNDAMENTAL INCOMPLETO  48     PRF  2012,55  13101,44  1  JANEIRO
# 3  ENSINO FUNDAMENTAL INCOMPLETO  48     PRF  2012,55  12080,44  1  JANEIRO
# 4          ENSINO MEDIO COMPLETO  44    SEDE     2250   5682,92  1  JANEIRO
#
#    2019  DPRF/MJ  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL/MJ  30802  \
# 0  2019  DPRF/MJ  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL/MJ  30802
# 1  2019  DPRF/MJ  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL/MJ  30802
# 2  2019  DPRF/MJ  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL/MJ  30802
# 3  2019  DPRF/MJ  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL/MJ  30802
# 4  2019  DPRF/MJ  DEPARTAMENTO DE POLICIA RODOVIARIA FEDERAL/MJ  30802
#
#    30802.1
# 0    30802
# 1    30802
# 2    30802
# 3    30802
# 4    30802

# %%
pd.set_option('display.max_columns', None)

# %%
df.shape
# Out:
# (81941, 23)

# %%
for ano in df['Ano_Carga'].unique():
    for mes in df['Num_Mes_Carga'].unique():
        particionamento = f"ano={ano}/mes={mes}"
        os.makedirs(f"output/{particionamento}", exist_ok=True)
        
        df_particionado = df[(df['Ano_Carga'] == ano) & (df['Num_Mes_Carga'] == mes)]
        
        df_particionado.to_parquet(f"output/{particionamento}/data.parquet", index=False,)
# Out:
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[38], line 8
#       4 os.makedirs(f"output/{particionamento}", exist_ok=True)
#       6 df_particionado = df[(df['Ano_Carga'] == ano) & (df['Num_Mes_Carga'] == mes)]
# ----> 8 df_particionado.to_parquet(f"output/{particionamento}/data.parquet", index=False,)
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/core/frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3131 >>> content = f.read()
#    3132 """
#    3133 from pandas.io.parquet import to_parquet
# -> 3135 return to_parquet(
#    3136     self,
#    3137     path,
#    3138     engine,
#    3139     compression=compression,
#    3140     index=index,
#    3141     partition_cols=partition_cols,
#    3142     storage_options=storage_options,
#    3143     filesystem=filesystem,
#    3144     **kwargs,
#    3145 )
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:486, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     484 if isinstance(partition_cols, str):
#     485     partition_cols = [partition_cols]
# --> 486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     490 impl.write(
#     491     df,
#     492     path_or_buf,
#    (...)    498     **kwargs,
#     499 )
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pyarrow/types.pxi:2226, in pyarrow.lib.register_extension_type()
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: A type extension with name pandas.period already defined

# %%
for x in os.listdir('input'):
    print(f"Processing {x}...")
    if x.endswith('.csv'):
        df = pd.read_csv(f'input/{x}', sep=';', encoding='utf-8', dtype=str)
        print(f"Loaded {x} with shape {df.shape}")
    elif x.endswith('.xlsx'):
        df = pd.read_excel(f'input/{x}')
        print(f"Loaded {x} with shape {df.shape}")
            
    
    for ano in df['Ano_Carga'].unique():
        for mes in df['Num_Mes_Carga'].unique():
            particionamento = f"ano={ano}/mes={mes}"
            os.makedirs(f"output/{particionamento}", exist_ok=True)
            
            df_particionado = df[(df['Ano_Carga'] == ano) & (df['Num_Mes_Carga'] == mes)]
            
            df_particionado.to_parquet(f"output/{particionamento}/data.parquet", index=False,)
# Out:
# Processing terceirizados202309.csv...
# Loaded terceirizados202309.csv with shape (81941, 23)
# ---------------------------------------------------------------------------
# ArrowKeyError                             Traceback (most recent call last)
# Cell In[48], line 18
#      14 os.makedirs(f"output/{particionamento}", exist_ok=True)
#      16 df_particionado = df[(df['Ano_Carga'] == ano) & (df['Num_Mes_Carga'] == mes)]
# ---> 18 df_particionado.to_parquet(f"output/{particionamento}/data.parquet", index=False,)
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/core/frame.py:3135, in DataFrame.to_parquet(self, path, engine, compression, index, partition_cols, storage_options, filesystem, **kwargs)
#    3032 """
#    3033 Write a DataFrame to the binary parquet format.
#    3034
#    (...)   3131 >>> content = f.read()
#    3132 """
#    3133 from pandas.io.parquet import to_parquet
# -> 3135 return to_parquet(
#    3136     self,
#    3137     path,
#    3138     engine,
#    3139     compression=compression,
#    3140     index=index,
#    3141     partition_cols=partition_cols,
#    3142     storage_options=storage_options,
#    3143     filesystem=filesystem,
#    3144     **kwargs,
#    3145 )
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:486, in to_parquet(df, path, engine, compression, index, storage_options, partition_cols, filesystem, **kwargs)
#     484 if isinstance(partition_cols, str):
#     485     partition_cols = [partition_cols]
# --> 486 impl = get_engine(engine)
#     488 path_or_buf: FilePath | WriteBuffer[bytes] = io.BytesIO() if path is None else path
#     490 impl.write(
#     491     df,
#     492     path_or_buf,
#    (...)    498     **kwargs,
#     499 )
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:64, in get_engine(engine)
#      62 for engine_class in engine_classes:
#      63     try:
# ---> 64         return engine_class()
#      65     except ImportError as err:
#      66         error_msgs += "\n - " + str(err)
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/io/parquet.py:170, in PyArrowImpl.__init__(self)
#     167 import pyarrow.parquet
#     169 # import utils to register the pyarrow extension types
# --> 170 import pandas.core.arrays.arrow.extension_types  # pyright: ignore[reportUnusedImport] # noqa: F401
#     172 self.api = pyarrow
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pandas/core/arrays/arrow/extension_types.py:59
#      57 # register the type with a dummy instance
#      58 _period_type = ArrowPeriodType("D")
# ---> 59 pyarrow.register_extension_type(_period_type)
#      62 class ArrowIntervalType(pyarrow.ExtensionType):
#      63     def __init__(self, subtype, closed: IntervalClosedType) -> None:
#      64         # attributes need to be set first before calling
#      65         # super init (as that calls serialize)
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pyarrow/types.pxi:2226, in pyarrow.lib.register_extension_type()
#
# File ~/iplanrio-desafio-data-eng/.venv/lib/python3.12/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowKeyError: A type extension with name pandas.period already defined

# %%
import duckdb

con = duckdb.connect()


con.execute("""
SELECT *
FROM teste.duckdb;
""").fetchall()
# Out:
# A execução de células com 'Python 3.12.3' requer o pacote ipykernel.
#
# Instale 'ipykernel' no ambiente Python.
#
# Comando: '/bin/python3 -m pip install ipykernel -U --user --force-reinstall'
